# %%
import importlib
import numpy as np
import scipy.special as special
import matplotlib.pyplot as plt
import warnings
import dimensional_variables as dv
import setup_parameters as sp

DimensionalVariable = dv.DimensionalVariable
from lsw import lsw as LSW

# %%
lsw = LSW(particles_type='DP',
          setup_geometry='enveloped',
          cavity_mode='TM010',
          cavity_sizes=[1,1,1e-5],
          masses=DimensionalVariable(
              array=np.logspace(-7,-5,100),
              dimension='eV',
              SI_unit='meter',),
          show_image=True,
         )
# Out:
# Enveloped geometry
# ${\rm TM}_{010}-{\rm mode}$
# $L = 1.00000$ $\rm{m};$
# $R_1 = 1.00000$ $\rm{m};$
# $R_2 = 1.00001$ $\rm{m};$
# $R_3 = 2.29543$ $\rm{m};$
# $d = 10$ $\mu\rm{m};$
# $J(p_\rho R_1) =$ $\tt1.024e-16$;
# $Z(p_\rho R_2) =$ $\tt0.000e+00$;
# $Z(p_\rho R_3) =$ $\tt4.008e-16$;
# $J'(p_\rho R_1) =$ $-0.52$;
# $Z'(p_\rho R_2) =$ $-0.52$;
# $Z'(p_\rho R_3) =$ $0.34$;
# $p_\rho R_3 Z'(p_\rho R_3)J(p_\rho R_3) - $$p_\rho R_2 Z'(p_\rho R_2)J(p_\rho R_2) = $$\tt7.527785e-16$;
# $p_\rho R_3 Z'(p_\rho R_3)Y(p_\rho R_3) - $$p_\rho R_2 Z'(p_\rho R_2)Y(p_\rho R_2) = $$\tt0.000000e+00$;
# The boundary conditions are met.

# %%
lsw.Calculate(True)
# Out:
# 1d-integration...
# 100%|█████████████████████████████████████████| 100/100 [00:05<00:00, 17.21it/s]
# 6d-integration...
# 100%|███████████████████████████████████████████| 10/10 [00:44<00:00,  4.42s/it]

# %%
lsw.get_plot_data(error_factor=10)
# Out:
# ${\tt Asymptotic\ for}\ m_{A'}R_1 \gg 1: \\{\tt 1.\ Precise\ asymptotic}: \\\epsilon = \left[\dfrac{2 T \, {\rm SNR}} {Q_{\rm rec} E_0^2 t}\right]^{1/4} \times\left[\dfrac{R_2}{R_1}\times \dfrac{\left(\frac{R_3 Z'_0(p_\rho R_3)}{R_2 Z'_0(p_\rho R_2)}\right)^2- 1}{\pi x_{01}}\right]^{1/4} \times\left(\dfrac{R_1}{L}\right)^{1/4} \times \varkappa_{A'}^{1/2}\left(\dfrac{\varkappa_{A'}} {m_{A'}} \right)^2 \times \exp\left(\dfrac{m_{A'}d}{2}\right) \\{\tt 2.\ Approximation}\ d \ll R_1: \\\epsilon = \left[\dfrac{2 T \, {\rm SNR}} {Q_{\rm rec} E_0^2 t}\right]^{1/4} \times\left[\dfrac{\left(\frac{x_{02}J'_0(x_{02})}{x_{01}J'_0(x_{01})}\right)^2- 1}{\pi x_{01}}\right]^{1/4} \times\left(\dfrac{R_1}{L}\right)^{1/4} \times m_{A'}^{1/2} \cdot \times \exp\left(\dfrac{m_{A'}d}{2}\right)$
# the plot data were written to the .plot_data attribute
# x-array: dimension = eV ^ 1.0, len = 100
# y-array: dimension = eV ^ 0.0, len = 100
